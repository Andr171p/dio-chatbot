# %%
import pandas as pd

# %%
FILE_PATH = r"C:\Users\andre\DIOManagerBot\raw\price_1c.xls"

# %%
df = pd.read_excel(FILE_PATH)
df.head(3)
# Out:
#                                       Unnamed: 0  Прайс-лист фирмы "1С"  \
# 0                                            Код           Наименование
# 1                       Раздел 1. 1С:ПРЕДПРИЯТИЕ                    NaN
# 2  1.1.    Программные продукты 1С:Предприятие 8                    NaN
#
#    Unnamed: 2 Unnamed: 3            Unnamed: 4       Unnamed: 5  \
# 0         NaN   Валюта *  Рекомендованная цена  Цена для дилера
# 1         NaN        NaN                   NaN              NaN
# 2         NaN        NaN                   NaN              NaN
#
#                Unnamed: 6       Unnamed: 7       28 марта 2025  \
# 0  Цена для пост партнера  Ставка НДС РФ**  Дата начала продаж
# 1                     NaN              NaN                 NaN
# 2                     NaN              NaN                 NaN
#
#                           Unnamed: 9  Unnamed: 10
# 0  Единый реестр российских программ  Комментарий
# 1                                NaN          NaN
# ...

# %%
df.shape
# Out:
# (8992, 11)

# %%
new_columns = df.iloc[0].values.tolist()
df.columns = new_columns
df = df.iloc[1:, :]
df.head(5)
# Out:
#                                              Код  \
# 1                       Раздел 1. 1С:ПРЕДПРИЯТИЕ
# 2  1.1.    Программные продукты 1С:Предприятие 8
# 3              1С:Предприятие 8 для Азербайджана
# 4                                  4601546118561
# 5                                  4601546061621
#
#                                         Наименование  NaN Валюта *  \
# 1                                                NaN  NaN      NaN
# 2                                                NaN  NaN      NaN
# 3                                                NaN  NaN      NaN
# 4  1С:Бухгалтерия 8 для Азербайджана. Электронная...  NaN      USD
# 5  1С:Бухгалтерия 8 для Азербайджана. Комплект на...  NaN      USD
#
#   Рекомендованная цена Цена для дилера Цена для пост партнера Ставка НДС РФ**  \
# 1                  NaN             NaN                    NaN             NaN
# 2                  NaN             NaN                    NaN             NaN
# ...

# %%
df = df.dropna(subset=['Наименование'])
df.head(3)
# Out:
#              Код                                       Наименование  NaN  \
# 4  4601546118561  1С:Бухгалтерия 8 для Азербайджана. Электронная...  NaN
# 5  4601546061621  1С:Бухгалтерия 8 для Азербайджана. Комплект на...  NaN
# 6  2900001741507  1С:Зарплата и управление персоналом 8 для Азер...  NaN
#
#   Валюта * Рекомендованная цена Цена для дилера Цена для пост партнера  \
# 4      USD                  276             138                    124
# 5      USD                  594             297                    267
# 6      USD                  406             203                    183
#
#   Ставка НДС РФ** Дата начала продаж Единый реестр российских программ  \
# 4             20%         07.08.2015                               NaN
# 5             20%         01.10.2015                               NaN
# 6             20%         05.09.2016                               NaN
#
#                                          Комментарий
# ...

# %%
df.shape
# Out:
# (8646, 11)

# %%
df = df.drop(df.columns[2], axis=1)
df.head(3)
# Out:
#              Код                                       Наименование Валюта *  \
# 4  4601546118561  1С:Бухгалтерия 8 для Азербайджана. Электронная...      USD
# 5  4601546061621  1С:Бухгалтерия 8 для Азербайджана. Комплект на...      USD
# 6  2900001741507  1С:Зарплата и управление персоналом 8 для Азер...      USD
#
#   Рекомендованная цена Цена для дилера Цена для пост партнера Ставка НДС РФ**  \
# 4                  276             138                    124             20%
# 5                  594             297                    267             20%
# 6                  406             203                    183             20%
#
#   Дата начала продаж Единый реестр российских программ  \
# 4         07.08.2015                               NaN
# 5         01.10.2015                               NaN
# 6         05.09.2016                               NaN
#
#                                          Комментарий
# 4  Цена действительна для покупателей нерезиденто...
# ...

# %%
df = df[["Код",	"Наименование",	"Валюта *",	"Рекомендованная цена"]]
df.head(3)
# Out:
#              Код                                       Наименование Валюта *  \
# 4  4601546118561  1С:Бухгалтерия 8 для Азербайджана. Электронная...      USD
# 5  4601546061621  1С:Бухгалтерия 8 для Азербайджана. Комплект на...      USD
# 6  2900001741507  1С:Зарплата и управление персоналом 8 для Азер...      USD
#
#   Рекомендованная цена
# 4                  276
# 5                  594
# 6                  406

# %%
df = df[df["Валюта *"] == "руб."]
df.shape
# Out:
# (7946, 4)

# %%
df = df.drop("Валюта *", axis=1)

# %%
df.to_csv("price_list.csv")
